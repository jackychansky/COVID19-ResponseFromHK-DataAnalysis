# %%
import pandas as pd

# %%
os.chdir('C:\\Users\\yeung\\Google Drive\\xecelerate\\FTDS_Aug2020_GroupProject1_Covid19\\ki\\g6p1\\for ppt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1655.csv',
#  'covidcum_hk.png',
#  'covidnew_hk.xlsx',
#  'covid_trend_hk-fromjc.ipynb',
#  'gtmaskdata',
#  'hkconfirmedcase.csv',
#  'hk_gt_case.jpg',
#  'immi+googletrend.csv',
#  'immi_gt_covidhk.csv',
#  'multiTimeline.csv',
#  'plotgraph.ipynb',
#  'two_different_y_axis_for_single_python_plot_with_twinx.jpg',
#  'Untitled.ipynb',
#  'usjpkrcase']

# %%
merge = pd.read_csv('1655.csv',index_col='Unnamed: 0')
merge.index=pd.DatetimeIndex(merge.index)

# %%
#merge.index=pd.DatetimeIndex(merge.index)

# %%
os.chdir('C:\\Users\\yeung\\Google Drive\\xecelerate\\FTDS_Aug2020_GroupProject1_Covid19\\ki\\g6p1\\for ppt\\usjpkrcase')

# %%
os.listdir()
# Out:
# ['covidnew_jp.xlsx', 'covidnew_kr.xlsx', 'covidnew_us.xlsx']

# %%
for i in os.listdir():
    covidconf = pd.read_excel(i,index_col='Date')
    covidconf.index=pd.DatetimeIndex(covidconf.index)
    merge = pd.merge(merge,covidconf, how='outer',  right_index=True,left_index=True)

# %%
merge
# Out:
#             Mask(Chi)  Mask(Eng)  Immigration(Chi)  Health(Chi)  Hiking(Chi)  \
# 2020-01-01          0          1                 0            1            1
# 2020-01-02          2          2                 1            1            1
# 2020-01-03          2          1                 1            1            1
# 2020-01-04          2          1                 1            1            1
# 2020-01-05          4          2                 1            1            1
# ...               ...        ...               ...          ...          ...
# 2020-06-26          8          3                 1            3            1
# 2020-06-27          7          3                 2            2            1
# 2020-06-28          6          3                 1            3            1
# 2020-06-29          6          3                 2            3            1
# 2020-06-30          6          3                 2            3            1
#
# ...

# %%
merge
# Out:
#             Mask(Chi)  Mask(Eng)  Immigration(Chi)  Health(Chi)  Hiking(Chi)  \
# 2020-01-01          0          1                 0            1            1
# 2020-01-02          2          2                 1            1            1
# 2020-01-03          2          1                 1            1            1
# 2020-01-04          2          1                 1            1            1
# 2020-01-05          4          2                 1            1            1
# ...               ...        ...               ...          ...          ...
# 2020-06-26          8          3                 1            3            1
# 2020-06-27          7          3                 2            2            1
# 2020-06-28          6          3                 1            3            1
# 2020-06-29          6          3                 2            3            1
# 2020-06-30          6          3                 2            3            1
#
# ...

# %%
merge = merge.sort_index()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(x = merge.index, y = "Confirmed", data = merge)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(merge.index , merge.Confirmed, color="red")
# set x-axis label
ax.set_xlabel("Date",fontsize=14)
# set y-axis label
ax.set_ylabel("Confirmed Case",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(merge.index, merge['Mask(Chi)'] ,color="blue")
ax2.set_ylabel("Mask Google Search",color="blue",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig('hk_gt_case.jpg',
            format='jpeg',
            dpi=600,
            bbox_inches='tight')

# %%
import os

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(merge.index , merge['Confirmed-JP'], color="red")
# set x-axis label
ax.set_xlabel("Date",fontsize=14)
# set y-axis label
ax.set_ylabel("Confirmed Case",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(merge.index, merge['jpmask'] ,color="blue")
ax2.set_ylabel("JP Mask Google Search",color="blue",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig('jp_gt_case.jpg',
            format='jpeg',
            dpi=600,
            bbox_inches='tight')

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(merge.index , merge['Confirmed-KR'], color="red")
# set x-axis label
ax.set_xlabel("Date",fontsize=14)
# set y-axis label
ax.set_ylabel("Confirmed Case",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(merge.index, merge['krmask'] ,color="blue")
ax2.set_ylabel("KR Mask Google Search",color="blue",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig('kr_gt_case.jpg',
            format='jpeg',
            dpi=600,
            bbox_inches='tight')

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(merge.index , merge['Confirmed-US'], color="red")
# set x-axis label
ax.set_xlabel("Date",fontsize=14)
# set y-axis label
ax.set_ylabel("Confirmed Case",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(merge.index, merge['usmask'] ,color="blue")
ax2.set_ylabel("US Mask Google Search",color="blue",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig('us_gt_case.jpg',
            format='jpeg',
            dpi=600,
            bbox_inches='tight')

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.scatter(merge.index , merge['Confirmed-US'], color="red")
# set x-axis label
ax.set_xlabel("Date",fontsize=14)
# set y-axis label
ax.set_ylabel("Confirmed Case",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.scatter(merge.index, merge['usmask'] ,color="blue")
ax2.set_ylabel("US Mask Google Search",color="blue",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig('us_gt_se.jpg',
            format='jpeg',
            dpi=600,

            bbox_inches='tight')

# %%
fig,ax = plt.subplots()
sns.lineplot(data=merge, x=merge.index, y='usmask',color="blue")
ax.set_ylabel("Confirmed Case",color="red",fontsize=14)

ax2=ax.twinx()
sns.lineplot(data=merge, x=merge.index, y='Confirmed-US', color='red')

# %%
twmask=pd.read_csv(r'C:\Users\yeung\Google Drive\xecelerate\FTDS_Aug2020_GroupProject1_Covid19\ki\g6p1\trenddata\twtrend.csv', index_col='Date')
twmask.index=pd.DatetimeIndex(twmask.index)

# %%
os.chdir('C:\\Users\\yeung\\Google Drive\\xecelerate\\FTDS_Aug2020_GroupProject1_Covid19\\ki\\g6p1\\for ppt\\usjpkrcase')

# %%
os.listdir()
# Out:
# ['covidnew_jp.xlsx',
#  'covidnew_kr.xlsx',
#  'covidnew_tw.xlsx',
#  'covidnew_us.xlsx']

# %%
twcovid = pd.read_excel('.\\covidnew_tw.xlsx', index_col='Date')
twcovid=twcovid.iloc[:,1:]
twcovid.index=pd.DatetimeIndex(twcovid.index)

# %%
# Out:
#             Unnamed: 0  Confirmed  Death
# Date
# 2020-01-22           0          1      0
# 2020-01-23           1          0      0
# 2020-01-24           2          2      0
# 2020-01-25           3          0      0
# 2020-01-26           4          1      0
# ...                ...        ...    ...
# 2020-09-10         219          0      0
# 2020-09-11         220          3      0
# 2020-09-12         221          0      0
# 2020-09-13         222          0      0
# 2020-09-14         223          0      0
#
# [224 rows x 3 columns]

# %%
twcombine = pd.merge(twmask,twcovid, how='left',  right_index=True,left_index=True)

# %%
twcombine=twcombine.sort_index()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(twcombine.index , twcombine.Confirmed, color="red")
# set x-axis label
ax.set_xlabel("Date",fontsize=14)
# set y-axis label
ax.set_ylabel("Confirmed Case",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(twcombine.index, twcombine['twmask'] ,color="blue")
ax2.set_ylabel("TW Mask Google Search",color="blue",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig('tw_gt_case.jpg',
            format='jpeg',
            dpi=600,
            bbox_inches='tight')
