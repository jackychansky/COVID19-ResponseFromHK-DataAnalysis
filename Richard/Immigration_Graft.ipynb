# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("ticks")

# %%
df = pd.read_csv('Immigration.csv', index_col=0)

# %%
df.Date = pd.DatetimeIndex(df.Date)

# %%
df.set_index("Date")
# Out:
#             Arr-HKres  Arr-MAINLANDvis  Arr-OTHERvis  Arr-Total  Dep-HKres  \
# Date
# 2020-01-24     102663            36705         22872     162240     294785
# 2020-01-25      86417            29891         19177     135485     186168
# 2020-01-26     163668            36690         16707     217065     121396
# 2020-01-27     177470            28780         12816     219066      90477
# 2020-01-28     188788            24156         10248     223192      81904
# ...               ...              ...           ...        ...        ...
# 2020-06-26       3194              110            80       3384       2694
# 2020-06-27       1588               81            75       1744       1006
# 2020-06-28       1567              124            82       1773       1222
# 2020-06-29       2759               88            44       2891       2486
# 2020-06-30       3426              169            95       3690       2931
#
#             Dep-MAINLANDvis  Dep-OTHERvis  Dep-Total
# Date
# ...

# %%
ax = df.iloc[:31,:].plot(figsize=(20,8), grid=True, title="Immigration Statistics")#, subplots=True)
ax.set_xlabel("Date")
ax.set_ylabel("People")
# Out:
# Text(0, 0.5, 'People')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159 entries, 2020-01-24 to 2020-06-30
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Arr-HKres        159 non-null    int64
#  1   Arr-MAINLANDvis  159 non-null    int64
#  2   Arr-OTHERvis     159 non-null    int64
#  3   Arr-Total        159 non-null    int64
#  4   Dep-HKres        159 non-null    int64
#  5   Dep-MAINLANDvis  159 non-null    int64
#  6   Dep-OTHERvis     159 non-null    int64
#  7   Dep-Total        159 non-null    int64
# dtypes: int64(8)
# memory usage: 11.2+ KB

# %%
df = pd.DatetimeIndex()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-f05113899b94> in <module>
# ----> 1 df = pd.DatetimeIndex()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in __new__(cls, data, freq, tz, normalize, closed, ambiguous, dayfirst, yearfirst, dtype, copy, name)
#     234
#     235         if is_scalar(data):
# --> 236             raise TypeError(
#     237                 f"{cls.__name__}() must be called with a "
#     238                 f"collection of some kind, {repr(data)} was passed"
#
# TypeError: DatetimeIndex() must be called with a collection of some kind, None was passed

# %%
df.iloc[31:60,:]
# Out:
#             Arr-HKres  Arr-MAINLANDvis  Arr-OTHERvis  Arr-Total  Dep-HKres  \
# Date
# 2020-02-24      16972              588          2410      19970      14216
# 2020-02-25      15207              558          2067      17832      12249
# 2020-02-26      14317              587          2157      17061      12748
# 2020-02-27      13846              702          2404      16952      14287
# 2020-02-28      15248              558          2642      18448      17148
# 2020-02-29      17881             1084          2797      21762      16533
# 2020-03-01      20991             1346          3237      25574      15755
# 2020-03-02      16629              973          2682      20284      14627
# 2020-03-03      13837              918          2682      17437      13452
# 2020-03-04      13264              973          2607      16844      13393
# 2020-03-05      13245              916          2534      16695      14729
# ...
